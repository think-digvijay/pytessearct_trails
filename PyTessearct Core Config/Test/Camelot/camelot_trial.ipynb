# %%
import camelot
import pandas as pd

# %%
file_loc = r'C:\Users\digvi\Desktop\ChiStats\PyTesseract\PyTessearct Core Config\Test\Test_Data\PRAXAIR DISTRIBUTION INC\4403780798\4403780798.pdf'

# %%
tables = camelot.read_pdf(filepath=file_loc)

# %%
tables
# Out:
# <TableList n=4>

# %%
tables.export('foo.csv', f='csv', compress=True)

# %%
tables[3]
# Out:
# <Table shape=(5, 10)>

# %%
tables[3].df
# Out:
#                                                    0  \
# 0  | TERMS:\nNet 60 Days \n|\nPAYMENT DUE: 1/13/2...
# 1  BACK\nQTY\nQTY \nUNIT\nTAX\nVOL/WT\nMil \nDMvr...
# 2  INVOICE NO:93079402\nSHIP FROM\nORDER REFERENC...
# 3  ACCOUNTS PAST DUE WILL BE CHARGED THE\nGREATER...
# 4
#
#                                                    1  \
# 0
# 1
# 2  CUSTOMER :71854970 DATE: 11 /14/2019\n70330,PX...
# 3  PAYMENT RECEIVED WITHOUT INVOICE APPLICATION I...
# 4
#
#                                       2 3 4 5 6                   7  \
# 0
# 1
# 2                                                12.70\n6.33\n35.00
# 3  SUBTOTAL\nTAX AMOUNT\nINVOICE AMOUNT
# 4       USD $\n1,822.20\n0.00\n1,822.20
#
#                                8         9
# 0
# 1
# 2  645.00\n889.00\n253.20\n35.00  N N N\nN
# 3
# 4

# %%
tables[3].to_csv('1.csv')

# %%
camelot.plot(tables[0], kind='contour').show()
# Out:
# <ipython-input-19-e96134b9efed>:1: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   camelot.plot(tables[0], kind='contour').show()

# %%
camelot.plot(tables[3], kind='line').show()
# Out:
# <ipython-input-27-934d5568f1d3>:1: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   camelot.plot(tables[3], kind='line').show()

# %%
region = tables[3]._bbox
# print(region)
# print(type(region))

str1 = str(region[0]) + ',' + str(region[1]) + ',' + str(region[2]) + ',' + str(region[3])
print((str1))
# Out:
# 28.314930011723334,43.921105624999996,601.572284232122,437.5310139583333

# %%
table_3 = camelot.read_pdf(filepath=file_loc, flavor='stream', table_areas=['28.314930011723334,437.5310139583333,601.572284232122,43.921105624999996'])

# %%
table_3[0].df
# Out:
#                                           0  \
# 0
# 1
# 2                               ITEM NUMBER
# 3
# 4                       INVOICE NO:93079402
# 5                                 SHIP FROM
# 6                           ORDER REFERENCE
# 7                     CUSTOMER PO / RELEASE
# 8                                  SHIP VIA
# 9
# 10                             UNB316L09336
# 11
# 12
# 13                             UNB316L12536
# 14                             UNB308L12536
# 15                          DROPSHIPFREIGHT
# 16    ACCOUNTS PAST DUE WILL BE CHARGED THE
# 17  GREATER OF A SERVICE CHARGE OF $1, OR A
# 18    FINANCE CHARGE OF 1.5% PER MONTH (18%
# 19  ANNUAL RATE) OF THE OUTSTANDINGBALANCE,
# 20        UNLESS OTHERWISE SPECIFIED IN THE
# 21                                CONTRACT.
#
#                                                     1         2          3  \
# 0             INVOICE DETAIL AND PURCHASE DESCRIPTION  | TERMS:
# ...

# %%
table_3[0].to_csv('2.csv')

# %%
table_4 = camelot.read_pdf(filepath='cropped.pdf', flavor='stream', strip_text=' .\n')

# %%
table_5 = camelot.read_pdf(filepath=file_loc, flavor='stream', table_areas=['28.314930011723334,417.5310139583333,651.572284232122,43.921105624999996'])

# %%
table_5[0].df
# Out:
#                                           0  \
# 0
# 1                               ITEM NUMBER
# 2
# 3                       INVOICE NO:93079402
# 4                                 SHIP FROM
# 5                           ORDER REFERENCE
# 6                     CUSTOMER PO / RELEASE
# 7                                  SHIP VIA
# 8
# 9                              UNB316L09336
# 10
# 11
# 12                             UNB316L12536
# 13                             UNB308L12536
# 14                          DROPSHIPFREIGHT
# 15    ACCOUNTS PAST DUE WILL BE CHARGED THE
# 16  GREATER OF A SERVICE CHARGE OF $1, OR A
# 17    FINANCE CHARGE OF 1.5% PER MONTH (18%
# 18  ANNUAL RATE) OF THE OUTSTANDINGBALANCE,
# 19        UNLESS OTHERWISE SPECIFIED IN THE
# 20                                CONTRACT.
#
#                                                     1     2          3  \
# 0                                                       QTY  QTY \nMil
# ...
