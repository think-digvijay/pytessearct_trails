# %%
import camelot
import pandas as pd
import os
import PyPDF2

# %%
file_loc = r'C:\Users\digvi\Desktop\ChiStats\PyTesseract\PyTessearct Core Config\Test\Camelot\Final\Data\PIPING TECHNOLOGY & PRODUCTS INC\4403756703\4403756703.pdf'

# %%
tables = camelot.read_pdf(filepath=file_loc)

try:
    line_plots = camelot.plot(tables[0], kind='line')
    print("tables found")

except:
    print("no tables found")
# Out:
# tables found

# %%
camelot.plot(tables[0], kind='contour').show()
# Out:
# <ipython-input-61-e96134b9efed>:1: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   camelot.plot(tables[0], kind='contour').show()

# %%
for table in tables:
    print(table._bbox)
# Out:
# (626.6320372064654, 502.4081349862259, 762.4703110704484, 543.9354199134199)
# (514.0734675205856, 397.9898173947265, 762.710308020738, 489.68590318772135)
# (60.71922842329979, 397.509733175915, 308.15608417200366, 488.48569264069266)
# (33.83956999085087, 19.20336875245966, 763.670295821897, 372.06526957890594)

# %%
all_bbox = []
for table in tables:
    temp = table._bbox
    temp = list(temp)
    temp[1], temp[3] = temp[3], temp[1] 
    all_bbox.append(temp)

# %%
all_bbox
# Out:
# [[626.6320372064654, 543.9354199134199, 762.4703110704484, 502.4081349862259],
#  [514.0734675205856, 489.68590318772135, 762.710308020738, 397.9898173947265],
#  [60.71922842329979, 488.48569264069266, 308.15608417200366, 397.509733175915],
#  [33.83956999085087, 372.06526957890594, 763.670295821897, 19.20336875245966]]

# %%
areas = []
for i in range(0, len(all_bbox)):
    x_len = all_bbox[i][2] - all_bbox[i][0]
    y_len = all_bbox[i][1] - all_bbox[i][3]

    area = x_len * y_len
    areas.append(area)
    print(area)

max_area = max(areas)
max_index = areas.index(max_area)
print(max_index)
# Out:
# 5640.994702767829
# 22799.025057801147
# 22510.805358686117
# 257529.45719828788
# 3

# %%
tables[max_index]._bbox
# Out:
# (17.996777549824152, 172.32433791666665, 560.0597173505276, 227.76573354166663)

# %%
x1 = tables[max_index]._bbox[0]
y1 = tables[max_index]._bbox[3]
x2 = tables[max_index]._bbox[2]
y2 = tables[max_index]._bbox[1]

coords = str()

print(x1)
print(y1)
print(x2)
print(y2)
# Out:
# 17.996777549824152
# 507.1327660416666
# 560.0597173505276
# 235.44592687499997

# %%
table_single = camelot.read_pdf(filepath=file_loc, flavor='stream', table_areas = ['{}, {}, {}, {}'.format(x1, y1, x2, y2)])
len(table_single)
table_single[0].to_csv('trial.csv')

# %%
len(tables)
# Out:
# 3

# %%
def print_func(x):
    if(x>10):
        print(x)

# %%
x = int(input("input number"))

try:
    print_func(x)
except:
    print("number is less than 10")

# %%
tables = camelot.read_pdf(filepath=file_loc, flavor='stream', pages='all')

# %%
len(tables)
# Out:
# 4

# %%
tables[1]._bbox
# Out:
# (14.400544135429264, 63.10900312622118, 780.0294740024185, 594.616386869871)

# %%
tables[0]._bbox
# Out:
# (14.400544135429264, 63.10900312622118, 780.0294740024185, 594.616386869871)

# %%
print(file_save_loc)
# Out:
# C:\Users\digvi\Desktop\ChiStats\PyTesseract\PyTessearct Core Config\Test\Camelot\Final\Data\MRC Global\4403818197

# %%
tables.export(file_name, f='csv')

# %%
directory = 'Data'
detected_dirs = []
exception_dirs = []

for root, subdirectories, files in os.walk(directory):
    for subdirectory in subdirectories:
        os.path.join(root, subdirectory)
        #print(root)
    for file in files:
        if(file.endswith('.pdf')):
            file_loc = os.path.join(root, file)
            file_name = os.path.splitext(file)[0]
            file_save_loc = os.path.dirname(file_loc)
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
