# %%
import camelot
import pandas as pd

# %%
file_loc = r'C:\Users\digvi\Desktop\ChiStats\PyTesseract\PyTessearct Core Config\Test\Test_Data\ROSEMOUNT INC\4403789930\4403789930.pdf'

# %%
tables = camelot.read_pdf(filepath=file_loc)

# %%
tables
# Out:
# <TableList n=2>

# %%
tables.export('.csv', f='csv', compress=True)

# %%
tables[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-df1a706926ac> in <module>
# ----> 1 tables[3]
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\camelot\core.py in __getitem__(self, idx)
#     676
#     677     def __getitem__(self, idx):
# --> 678         return self._tables[idx]
#     679
#     680     @staticmethod
#
# IndexError: list index out of range

# %%
tables[0].df
# Out:
#                                                    0  \
# 0  150125633\nMail Invoice To:\nEQUISTAR CHEMICAL...
# 1
# 2
# 3
# 4
#
#                                                    1  \
# 0  Due Date:\nInvoice Date:\nInvoice No:\n7157243...
# 1             Payment Terms:\nPayment due in 30 days
# 2                                      Rep Order No:
# 3                 Customer Order Number:\n4403789930
# 4                                        Project No:
#
#                                      2
# 0
# 1
# 2  Sales Order No:\n4150-10495-5714842
# 3
# 4

# %%
tables[1].to_csv('1.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-9-6e10b9ad512b> in <module>
# ----> 1 tables[1].to_csv('1.csv')
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\camelot\core.py in to_csv(self, path, **kwargs)
#     581         kw = {"encoding": "utf-8", "index": False, "header": False, "quoting": 1}
#     582         kw.update(kwargs)
# --> 583         self.df.to_csv(path, **kw)
#     584
#     585     def to_json(self, path, **kwargs):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3165             decimal=decimal,
#    3166         )
# -> 3167         formatter.save()
#    3168
# ...

# %%
camelot.plot(tables[0], kind='contour').show()
# Out:
# <ipython-input-11-e96134b9efed>:1: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   camelot.plot(tables[0], kind='contour').show()

# %%
camelot.plot(tables[0], kind='line').show()
# Out:
# <ipython-input-13-1fcb01d35d05>:1: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   camelot.plot(tables[0], kind='line').show()

# %%
region = tables[]._bbox
# print(region)
# print(type(region))

str1 = str(region[0]) + ',' + str(region[1]) + ',' + str(region[2]) + ',' + str(region[3])
print((str1))
# Out:
#   File "<ipython-input-21-80f8e6877eb4>", line 1
#     region = tables[]._bbox
#                     ^
# SyntaxError: invalid syntax

# %%
table_3 = camelot.read_pdf(filepath=file_loc, flavor='stream', table_areas=[',437.5310139583333,601.572284232122,43.921105624999996'])

# %%
table_3[0].df
# Out:
#                                           0  \
# 0
# 1
# 2                               ITEM NUMBER
# 3
# 4                       INVOICE NO:93079402
# 5                                 SHIP FROM
# 6                           ORDER REFERENCE
# 7                     CUSTOMER PO / RELEASE
# 8                                  SHIP VIA
# 9
# 10                             UNB316L09336
# 11
# 12
# 13                             UNB316L12536
# 14                             UNB308L12536
# 15                          DROPSHIPFREIGHT
# 16    ACCOUNTS PAST DUE WILL BE CHARGED THE
# 17  GREATER OF A SERVICE CHARGE OF $1, OR A
# 18    FINANCE CHARGE OF 1.5% PER MONTH (18%
# 19  ANNUAL RATE) OF THE OUTSTANDINGBALANCE,
# 20        UNLESS OTHERWISE SPECIFIED IN THE
# 21                                CONTRACT.
#
#                                                     1         2          3  \
# 0             INVOICE DETAIL AND PURCHASE DESCRIPTION  | TERMS:
# ...

# %%
table_3[0].to_csv('2.csv')

# %%
table_4 = camelot.read_pdf(filepath='cropped.pdf', flavor='stream', strip_text=' .\n')

# %%
table_5 = camelot.read_pdf(filepath=file_loc, flavor='stream', table_areas=['28.314930011723334,417.5310139583333,651.572284232122,43.921105624999996'])

# %%
table_5[0].df
# Out:
#                                           0  \
# 0
# 1                               ITEM NUMBER
# 2
# 3                       INVOICE NO:93079402
# 4                                 SHIP FROM
# 5                           ORDER REFERENCE
# 6                     CUSTOMER PO / RELEASE
# 7                                  SHIP VIA
# 8
# 9                              UNB316L09336
# 10
# 11
# 12                             UNB316L12536
# 13                             UNB308L12536
# 14                          DROPSHIPFREIGHT
# 15    ACCOUNTS PAST DUE WILL BE CHARGED THE
# 16  GREATER OF A SERVICE CHARGE OF $1, OR A
# 17    FINANCE CHARGE OF 1.5% PER MONTH (18%
# 18  ANNUAL RATE) OF THE OUTSTANDINGBALANCE,
# 19        UNLESS OTHERWISE SPECIFIED IN THE
# 20                                CONTRACT.
#
#                                                     1     2          3  \
# 0                                                       QTY  QTY \nMil
# ...
